# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.simplefilter('ignore')

# %%
df=pd.read_csv('Data.csv')

# %%
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
df.shape
# Out:
# (1303, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   object
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   object
#  10  Price             1303 non-null   float64
# dtypes: float64(2), object(9)
# memory usage: 112.1+ KB

# %%
df['Ram']=df['Ram'].str.replace('GB','')
df['Weight']=df['Weight'].str.replace('kg','')

# %%
df['Ram']=df['Ram'].astype('int32')
df['Weight']=df['Weight'].astype('float32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
# dtypes: float32(1), float64(2), int32(1), object(7)
# memory usage: 101.9+ KB

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232
# ...

# %% [markdown]
# # EDA

# %% [markdown]
# # Univariate Analysis

# %%
sns.distplot(df['Price'])
# Out:
# <AxesSubplot: xlabel='Price', ylabel='Density'>

# %%
# there are many laptop which have less price also there are many laptop which have high price but are in less number

# %%
sns.countplot(data=df,x='Company')
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(data=df,x='Company',y='Price')
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.countplot(data=df,x='TypeName')
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(data=df,x='TypeName',y='Price')
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.distplot(df['Inches'])
# Out:
# <AxesSubplot: xlabel='Inches', ylabel='Density'>

# %%
sns.scatterplot(x=df['Inches'],y=df['Price'])
# Out:
# <AxesSubplot: xlabel='Inches', ylabel='Price'>

# %%
df['ScreenResolution'].value_counts()
# Out:
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# Touchscreen 2256x1504                              6
# ...

# %%
df['TouchScreen']=df['ScreenResolution'].apply(lambda x:1 if 'Touchscreen' in x else 0)

# %%
df.sample(5)
# Out:
#       Company            TypeName  Inches                  ScreenResolution  \
# 266      Asus  2 in 1 Convertible    13.3   Full HD / Touchscreen 1920x1080
# 1136       HP         Workstation    17.3       IPS Panel Full HD 1920x1080
# 913        HP            Notebook    15.6                 Full HD 1920x1080
# 274   Toshiba            Notebook    15.6                          1366x768
# 111      Dell           Ultrabook    13.3  Quad HD+ / Touchscreen 3200x1800
#
#                               Cpu  Ram                 Memory  \
# 266    Intel Core i7 8550U 1.8GHz    8  512GB SSD + 512GB SSD
# 1136  Intel Core i7 6700HQ 2.6GHz    8              256GB SSD
# 913    Intel Core i7 7500U 2.7GHz    8              256GB SSD
# 274    Intel Core i7 6500U 2.5GHz    8              500GB HDD
# 111    Intel Core i7 7560U 2.4GHz    8              256GB SSD
#
#                                Gpu       OpSys  Weight        Price  \
# ...

# %%
sns.countplot(data=df,x='TouchScreen')
plt.xticks(rotation='vertical')
plt.show()

# %%
# Touch Screen ka jaada price h
sns.barplot(data=df,x='TouchScreen',y='Price')
plt.xticks(rotation='vertical')
plt.show()

# %%
df['IPS']=df['ScreenResolution'].apply(lambda x:1 if 'IPS' in x else 0)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  TouchScreen  IPS
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# ...

# %%
sns.countplot(data=df,x='IPS')
plt.xticks(rotation='vertical')
plt.show()

# %%
# IPS display ka jaada price h
sns.barplot(data=df,x='IPS',y='Price')
plt.xticks(rotation='vertical')
plt.show()

# %%
new=df['ScreenResolution'].str.split('x',n=1,expand=True)

# %%
df['X_resoulution']=new[0]
df['y_resoulution']=new[1]

# %%
df['X_resoulution']=df['X_resoulution'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
#  11  TouchScreen       1303 non-null   int64
#  12  IPS               1303 non-null   int64
#  13  X_resoulution     1303 non-null   object
#  14  y_resoulution     1303 non-null   object
# dtypes: float32(1), float64(2), int32(1), int64(2), object(9)
# ...

# %%
df['X_resoulution']=df['X_resoulution'].astype('int')
df['y_resoulution']=df['y_resoulution'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
#  11  TouchScreen       1303 non-null   int64
#  12  IPS               1303 non-null   int64
#  13  X_resoulution     1303 non-null   int32
#  14  y_resoulution     1303 non-null   int32
# dtypes: float32(1), float64(2), int32(3), int64(2), object(7)
# ...

# %%
df.corr()['Price']
# Out:
# Inches           0.068197
# Ram              0.743007
# Weight           0.210370
# Price            1.000000
# TouchScreen      0.191226
# IPS              0.252208
# X_resoulution    0.556529
# y_resoulution    0.552809
# Name: Price, dtype: float64

# %%
df['ppi']=(((df['X_resoulution'])**2+ (df['y_resoulution']**2))**0.5/df['Inches']).astype('float')

# %%
df.corr()['Price']
# Out:
# Inches           0.068197
# Ram              0.743007
# Weight           0.210370
# Price            1.000000
# TouchScreen      0.191226
# IPS              0.252208
# X_resoulution    0.556529
# y_resoulution    0.552809
# ppi              0.473487
# Name: Price, dtype: float64

# %%
df.drop(columns=['ScreenResolution','X_resoulution','y_resoulution','Inches'],inplace=True)

# %%
df['Cpu'].value_counts()
# Out:
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: Cpu, Length: 118, dtype: int64

# %%
df['cpu_name']=df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))

# %%
df.sample(15)
# Out:
#       Company            TypeName                          Cpu  Ram  \
# 11         HP            Notebook     Intel Core i3 6006U 2GHz    4
# 1130       HP            Notebook   Intel Core i7 7500U 2.7GHz    8
# 1216     Acer            Notebook     Intel Core i3 6006U 2GHz    4
# 244    Lenovo  2 in 1 Convertible   Intel Core i7 7500U 2.7GHz    8
# 77       Dell            Notebook   Intel Core i7 8550U 1.8GHz    8
# 895   Toshiba            Notebook   Intel Core i5 7200U 2.5GHz    8
# 341    Lenovo            Notebook  AMD A12-Series 9720P 3.6GHz   12
# 121       MSI              Gaming  Intel Core i7 7700HQ 2.8GHz   16
# 235      Dell            Notebook   Intel Core i7 7500U 2.7GHz   16
# 1138      MSI              Gaming  Intel Core i7 6820HQ 2.7GHz   16
# 612      Dell            Notebook   Intel Core i3 6006U 2.0GHz    4
# 190    Lenovo  2 in 1 Convertible   Intel Core i7 7500U 2.7GHz   16
# 82         HP            Notebook   Intel Core i5 8250U 1.6GHz    8
# ...

# %%
def fetch_processor(text):
    if text == 'Intel Core i7' or text == 'Intel Core i3' or text == 'Intel Core i5':
        return text
    else:
        if text.split()[0] == 'Intel':
            return 'Other Intel Processor'
        else:
            return 'AMD Processor'

# %%
df['Cpu_Brand']=df['cpu_name'].apply(fetch_processor)

# %%
sns.barplot(data=df,x='Cpu_Brand',y='Price')
plt.xticks(rotation='vertical')
plt.show()

# %%
df.drop(columns=['Cpu','cpu_name'],inplace=True)

# %%
df
# Out:
#      Company            TypeName  Ram               Memory  \
# 0      Apple           Ultrabook    8            128GB SSD
# 1      Apple           Ultrabook    8  128GB Flash Storage
# 2         HP            Notebook    8            256GB SSD
# 3      Apple           Ultrabook   16            512GB SSD
# 4      Apple           Ultrabook    8            256GB SSD
# ...      ...                 ...  ...                  ...
# 1298  Lenovo  2 in 1 Convertible    4            128GB SSD
# 1299  Lenovo  2 in 1 Convertible   16            512GB SSD
# 1300  Lenovo            Notebook    2   64GB Flash Storage
# 1301      HP            Notebook    6              1TB HDD
# 1302    Asus            Notebook    4            500GB HDD
#
#                                Gpu       OpSys  Weight        Price  \
# 0     Intel Iris Plus Graphics 640       macOS    1.37   71378.6832
# 1           Intel HD Graphics 6000       macOS    1.34   47895.5232
# ...

# %%
# RAm column
sns.barplot(data=df,x='Ram',y='Price')
plt.xticks(rotation='vertical')
plt.show()

# %%
df
# Out:
#      Company            TypeName  Ram             Memory  \
# 0      Apple           Ultrabook    8            128 SSD
# 1      Apple           Ultrabook    8  128 Flash Storage
# 2         HP            Notebook    8            256 SSD
# 3      Apple           Ultrabook   16            512 SSD
# 4      Apple           Ultrabook    8            256 SSD
# ...      ...                 ...  ...                ...
# 1298  Lenovo  2 in 1 Convertible    4            128 SSD
# 1299  Lenovo  2 in 1 Convertible   16            512 SSD
# 1300  Lenovo            Notebook    2   64 Flash Storage
# 1301      HP            Notebook    6           1000 HDD
# 1302    Asus            Notebook    4            500 HDD
#
#                                Gpu       OpSys  Weight        Price  \
# 0     Intel Iris Plus Graphics 640       macOS    1.37   71378.6832
# 1           Intel HD Graphics 6000       macOS    1.34   47895.5232
# 2            Intel HD Graphics 620       No OS    1.86   30636.0000
# ...

# %%
# Memory
df['Memory'].value_counts()
# SSD,HDD,Flash Stroage,Hybrid
# Out:
# 256GB SSD                       412
# 1TB HDD                         223
# 500GB HDD                       132
# 512GB SSD                       118
# 128GB SSD + 1TB HDD              94
# 128GB SSD                        76
# 256GB SSD + 1TB HDD              73
# 32GB Flash Storage               38
# 2TB HDD                          16
# 64GB Flash Storage               15
# 512GB SSD + 1TB HDD              14
# 1TB SSD                          14
# 256GB SSD + 2TB HDD              10
# 1.0TB Hybrid                      9
# 256GB Flash Storage               8
# 16GB Flash Storage                7
# 32GB SSD                          6
# 180GB SSD                         5
# 128GB Flash Storage               4
# 512GB SSD + 2TB HDD               3
# 16GB SSD                          3
# 512GB Flash Storage               2
# 1TB SSD + 1TB HDD                 2
# 256GB SSD + 500GB HDD             2
# 128GB SSD + 2TB HDD               2
# 256GB SSD + 256GB SSD             2
# ...

# %%
df['Memory']=df['Memory'].astype('str').replace('\.0','',regex=True)
df['Memory']=df['Memory'].str.replace('GB','')
df['Memory']=df['Memory'].str.replace('TB','000')

# %%
df['Memory'].value_counts()
# Out:
# 256 SSD                        412
# 1000 HDD                       224
# 500 HDD                        132
# 512 SSD                        118
# 128 SSD + 1000 HDD              94
# 128 SSD                         76
# 256 SSD + 1000 HDD              73
# 32 Flash Storage                38
# 2000 HDD                        16
# 64 Flash Storage                15
# 512 SSD + 1000 HDD              14
# 1000 SSD                        14
# 256 SSD + 2000 HDD              10
# 1000 Hybrid                      9
# 256 Flash Storage                8
# 16 Flash Storage                 7
# 32 SSD                           6
# 180 SSD                          5
# 128 Flash Storage                4
# 512 SSD + 2000 HDD               3
# 16 SSD                           3
# 512 Flash Storage                2
# 1000 SSD + 1000 HDD              2
# 256 SSD + 500 HDD                2
# 128 SSD + 2000 HDD               2
# 256 SSD + 256 SSD                2
# 512 SSD + 256 SSD                1
# ...

# %%
new=df['Memory'].str.split('+',n=1,expand=True)
new[1].value_counts()
# Out:
#  1000 HDD       185
#  2000 HDD        15
#  256 SSD          3
#  500 HDD          2
#  1000 Hybrid      2
#  512 SSD          1
# Name: 1, dtype: int64

# %%
df['First']=new[0]
df['Second']=new[1]

# %%
df['Layer1HDD']=df['First'].apply(lambda x:1 if "HDD" in x else 0)
df['Layer1SDD']=df['First'].apply(lambda x:1 if "SSD" in x else 0)
df['Layer1Hybrid']=df['First'].apply(lambda x:1 if "Hybrid" in x else 0)
df['Layer1Flash_Storage']=df['First'].apply(lambda x:1 if "Flash Storage" in x else 0)

# %%
df['First']=df['First'].str.replace(r'\D','')

# %%
df
# Out:
#      Company            TypeName  Ram             Memory  \
# 0      Apple           Ultrabook    8            128 SSD
# 1      Apple           Ultrabook    8  128 Flash Storage
# 2         HP            Notebook    8            256 SSD
# 3      Apple           Ultrabook   16            512 SSD
# 4      Apple           Ultrabook    8            256 SSD
# ...      ...                 ...  ...                ...
# 1298  Lenovo  2 in 1 Convertible    4            128 SSD
# 1299  Lenovo  2 in 1 Convertible   16            512 SSD
# 1300  Lenovo            Notebook    2   64 Flash Storage
# 1301      HP            Notebook    6           1000 HDD
# 1302    Asus            Notebook    4            500 HDD
#
#                                Gpu       OpSys  Weight        Price  \
# 0     Intel Iris Plus Graphics 640       macOS    1.37   71378.6832
# 1           Intel HD Graphics 6000       macOS    1.34   47895.5232
# 2            Intel HD Graphics 620       No OS    1.86   30636.0000
# ...

# %%
df['Second'].fillna("0",inplace=True)

# %%
df['Second'].value_counts()
# Out:
# 0               1095
#  1000 HDD        185
#  2000 HDD         15
#  256 SSD           3
#  500 HDD           2
#  1000 Hybrid       2
#  512 SSD           1
# Name: Second, dtype: int64

# %%
df['Layer2HDD']=df['Second'].apply(lambda x:1 if "HDD" in x else 0)
df['Layer2SSD']=df['Second'].apply(lambda x:1 if "SSD" in x else 0)
df['Layer2Hybrid']=df['Second'].apply(lambda x:1 if "Hybrid" in x else 0)
df['Layer2Flash_Storage']=df['Second'].apply(lambda x:1 if "Flash Storage" in x else 0)

# %%
df['Second']=df['Second'].str.replace(r'\D','')

# %%
df.head()
# Out:
#   Company   TypeName  Ram             Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128 SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128 Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256 SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512 SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256 SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  TouchScreen  IPS  ...  First Second  Layer1HDD  \
# 0  macOS    1.37   71378.6832            0    1  ...    128      0          0
# 1  macOS    1.34   47895.5232            0    0  ...    128      0          0
# 2  No OS    1.86   30636.0000            0    0  ...    256      0          0
# 3  macOS    1.83  135195.3360            0    1  ...    512      0          0
# 4  macOS    1.37   96095.8080            0    1  ...    256      0          0
#
# ...

# %%
df['First']=df['First'].astype(int)

# %%
df['Second']=df['Second'].astype(int)

# %%
newdf=df.copy()

# %%
newdf['Layer1HDD']=newdf['First']*newdf['Layer1HDD']
newdf['Layer1SDD']=newdf['First']*newdf['Layer1SDD']
newdf['Layer1Hybrid']=newdf['First']*newdf['Layer1Hybrid']
newdf['Layer1Flash_Storage']=newdf['First']*newdf['Layer1Flash_Storage']

# %%
newdf['Layer2HDD']=newdf['Second']*newdf['Layer2HDD']
newdf['Layer2SSD']=newdf['Second']*newdf['Layer2SSD']
newdf['Layer2Hybrid']=newdf['Second']*newdf['Layer2Hybrid']
newdf['Layer2Flash_Storagee']=newdf['Second']*newdf['Layer2Flash_Storage']

# %%
newdf.sample(10)
# Out:
#      Company   TypeName  Ram              Memory                        Gpu  \
# 1113      HP  Ultrabook    8             512 SSD      Intel HD Graphics 520
# 714     Dell   Notebook   16             512 SSD      Intel HD Graphics 620
# 364   Lenovo   Notebook    8             256 SSD       Nvidia GeForce 920MX
# 1036      HP   Notebook    4             500 HDD      Intel HD Graphics 620
# 1208    Acer   Notebook    8            1000 HDD       Nvidia GeForce 940MX
# 873   Lenovo   Notebook    4             180 SSD      Intel HD Graphics 620
# 511     Acer   Notebook    4             500 HDD       Nvidia GeForce 940MX
# 587   Lenovo  Ultrabook   12             256 SSD      Intel HD Graphics 520
# 519     Asus     Gaming   16  256 SSD + 1000 HDD  Nvidia GeForce GTX1050 Ti
# 1100    Dell  Ultrabook    4             500 HDD      Intel HD Graphics 520
#
#            OpSys  Weight        Price  TouchScreen  IPS  ...  Second  \
# ...

# %%
df['Second'].value_counts()
# Out:
# 0       1095
# 1000     187
# 2000      15
# 256        3
# 500        2
# 512        1
# Name: Second, dtype: int64

# %%
df['Layer2HDD'].value_counts()
# Out:
# 0    1101
# 1     202
# Name: Layer2HDD, dtype: int64

# %%
df1=df.copy()

# %%
df1
# Out:
#      Company            TypeName  Ram             Memory  \
# 0      Apple           Ultrabook    8            128 SSD
# 1      Apple           Ultrabook    8  128 Flash Storage
# 2         HP            Notebook    8            256 SSD
# 3      Apple           Ultrabook   16            512 SSD
# 4      Apple           Ultrabook    8            256 SSD
# ...      ...                 ...  ...                ...
# 1298  Lenovo  2 in 1 Convertible    4            128 SSD
# 1299  Lenovo  2 in 1 Convertible   16            512 SSD
# 1300  Lenovo            Notebook    2   64 Flash Storage
# 1301      HP            Notebook    6           1000 HDD
# 1302    Asus            Notebook    4            500 HDD
#
#                                Gpu       OpSys  Weight        Price  \
# 0     Intel Iris Plus Graphics 640       macOS    1.37   71378.6832
# 1           Intel HD Graphics 6000       macOS    1.34   47895.5232
# 2            Intel HD Graphics 620       No OS    1.86   30636.0000
# ...

# %%
df1['Layer1HDD']=df1['First']*df1['Layer1HDD']

# %%
df1['Layer1SDD']=df1['First']*df1['Layer1SDD']

# %%
df1['Layer1Hybrid']=df1['First']*df1['Layer1Hybrid']

# %%
df1['Layer1Flash_Storage']=df1['First']*df1['Layer1Flash_Storage']

# %%
df1['Layer2HDD']=df1['Second']*df1['Layer2HDD']

# %%
df1['Layer2SSD']=df1['Second']*df1['Layer2SSD']

# %%
df1['Layer2Hybrid']=df1['Second']*df1['Layer2Hybrid']

# %%
df1['Layer2Flash_Storagee']=df1['Second']*df1['Layer2Flash_Storage']

# %%
df1.sample(10)
# Out:
#     Company   TypeName  Ram              Memory                           Gpu  \
# 39       HP   Notebook    8             256 SSD          Nvidia GeForce 930MX
# 864    Dell  Ultrabook   16             512 SSD  Intel Iris Plus Graphics 640
# 293    Dell   Notebook    8             256 SSD       Nvidia GeForce GTX 1050
# 226    Dell   Notebook   16            1000 HDD            AMD Radeon R7 M445
# 418    Dell   Notebook    8            1000 HDD         Intel HD Graphics 620
# 287    Asus  Ultrabook    8             256 SSD          Nvidia GeForce 940MX
# 863  Lenovo     Gaming    8            1000 HDD       Nvidia GeForce GTX 1050
# 166    Acer   Notebook    4            1000 HDD         Intel HD Graphics 505
# 77     Dell   Notebook    8  128 SSD + 1000 HDD        Intel UHD Graphics 620
# 754    Asus   Notebook    4             256 SSD         Intel HD Graphics 620
#
#           OpSys  Weight        Price  TouchScreen  IPS  ...  Second Layer1HDD  \
# ...

# %%
df1['SSD']=df1['Layer1SDD']+df1['Layer2SSD']
df1['HDD']=df1['Layer1HDD']+df1['Layer2HDD']
df1['Hybrid']=df1['Layer1Hybrid']+df1['Layer2Hybrid']
df1['Flash_Storage']=df1['Layer1Flash_Storage']+df1['Layer2Flash_Storage']

# %%
df1.sample(10)
# Out:
#      Company            TypeName  Ram              Memory  \
# 887     Asus              Gaming   12  128 SSD + 1000 HDD
# 627   Lenovo            Notebook    4             128 SSD
# 1159      HP  2 in 1 Convertible    8             512 SSD
# 958     Dell           Ultrabook    8             256 SSD
# 1202    Dell  2 in 1 Convertible   16             512 SSD
# 1285  Lenovo  2 in 1 Convertible   16             512 SSD
# 314     Asus  2 in 1 Convertible    2    32 Flash Storage
# 548       HP            Notebook    4             500 HDD
# 987   Lenovo              Gaming    8  128 SSD + 1000 HDD
# 12     Apple           Ultrabook   16             256 SSD
#
#                           Gpu       OpSys  Weight        Price  TouchScreen  \
# 887   Nvidia GeForce GTX 1050  Windows 10    2.20   72988.2720            0
# 627     Intel HD Graphics 620       No OS    2.20   24935.0400            0
# 1159    Intel HD Graphics 520  Windows 10    1.48  108744.4800            1
# ...

# %%
df1.drop(columns=['Layer1Flash_Storage','Layer1Hybrid','Layer1SDD','Layer1HDD','Layer2Flash_Storage','Layer2Hybrid','Layer2SSD','Layer2HDD'],inplace=True)

# %%
df1.drop(columns=['First','Second'],inplace=True)

# %%
df1.corr()['Price']
# Out:
# Ram              0.743007
# Weight           0.210370
# Price            1.000000
# TouchScreen      0.191226
# IPS              0.252208
# ppi              0.473487
# SSD              0.670799
# HDD             -0.096441
# Hybrid           0.007989
# Flash_Storage   -0.040511
# Name: Price, dtype: float64

# %%
df1.drop(columns=['HDD','Flash_Storage'],inplace=True)

# %%
df1.corr()['Price']
# Out:
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# TouchScreen    0.191226
# IPS            0.252208
# ppi            0.473487
# SSD            0.670799
# Hybrid         0.007989
# Name: Price, dtype: float64

# %%
df1
# Out:
#      Company            TypeName  Ram             Memory  \
# 0      Apple           Ultrabook    8            128 SSD
# 1      Apple           Ultrabook    8  128 Flash Storage
# 2         HP            Notebook    8            256 SSD
# 3      Apple           Ultrabook   16            512 SSD
# 4      Apple           Ultrabook    8            256 SSD
# ...      ...                 ...  ...                ...
# 1298  Lenovo  2 in 1 Convertible    4            128 SSD
# 1299  Lenovo  2 in 1 Convertible   16            512 SSD
# 1300  Lenovo            Notebook    2   64 Flash Storage
# 1301      HP            Notebook    6           1000 HDD
# 1302    Asus            Notebook    4            500 HDD
#
#                                Gpu       OpSys  Weight        Price  \
# 0     Intel Iris Plus Graphics 640       macOS    1.37   71378.6832
# 1           Intel HD Graphics 6000       macOS    1.34   47895.5232
# 2            Intel HD Graphics 620       No OS    1.86   30636.0000
# ...

# %%
# gpu column
df1['Gpu'].value_counts()
# Out:
# Intel HD Graphics 620      282
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# Intel Graphics 620           1
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# ARM Mali T860 MP4            1
# Name: Gpu, Length: 106, dtype: int64

# %%
df1['Gpu Brand']=df1['Gpu'].apply(lambda x:x.split()[0])

# %%
sns.countplot(data=df1,x='Gpu Brand')
# Out:
# <AxesSubplot: xlabel='Gpu Brand', ylabel='count'>

# %%
df1=df1[df1['Gpu Brand']!='ARM']

# %%
sns.barplot(data=df1,x='Gpu Brand',y='Price',estimator=np.median)
# Out:
# <AxesSubplot: xlabel='Gpu Brand', ylabel='Price'>

# %%
df1.drop(columns=['Gpu'],inplace=True)

# %%
# OpSys Column
df1['OpSys'].value_counts()
# Out:
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         27
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: OpSys, dtype: int64

# %%
sns.countplot(data=df1,x='OpSys')
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(data=df1,x='OpSys',y='Price',estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
def OpSys(inp):
    if inp=='Windows 10' or int=='Windows 7' or int=='Windows 10 S':
        return 'Windows'
    elif inp=='macOS' or inp=='Mac OS X':
        return 'Mac'
    else:
        return 'Other/No OS/ Linux'

# %%
df1['os']=df1['OpSys'].apply(OpSys)

# %%
sns.barplot(data=df1,x='os',y='Price',estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
df1.drop(columns=['OpSys'],inplace=True)

# %%
df1
# Out:
#      Company            TypeName  Ram             Memory  Weight        Price  \
# 0      Apple           Ultrabook    8            128 SSD    1.37   71378.6832
# 1      Apple           Ultrabook    8  128 Flash Storage    1.34   47895.5232
# 2         HP            Notebook    8            256 SSD    1.86   30636.0000
# 3      Apple           Ultrabook   16            512 SSD    1.83  135195.3360
# 4      Apple           Ultrabook    8            256 SSD    1.37   96095.8080
# ...      ...                 ...  ...                ...     ...          ...
# 1298  Lenovo  2 in 1 Convertible    4            128 SSD    1.80   33992.6400
# 1299  Lenovo  2 in 1 Convertible   16            512 SSD    1.30   79866.7200
# 1300  Lenovo            Notebook    2   64 Flash Storage    1.50   12201.1200
# 1301      HP            Notebook    6           1000 HDD    2.19   40705.9200
# 1302    Asus            Notebook    4            500 HDD    2.20   19660.3200
#
# ...

# %%
sns.distplot(df['Weight'])
# Out:
# <AxesSubplot: xlabel='Weight', ylabel='Density'>

# %%
sns.scatterplot(x=df1['Weight'],y=df['Price'])
# Out:
# <AxesSubplot: xlabel='Weight', ylabel='Price'>

# %%
sns.heatmap(df1.corr())
# Out:
# <AxesSubplot: >

# %%
sns.distplot(np.log(df['Price']))
# Out:
# <AxesSubplot: xlabel='Price', ylabel='Density'>

# %%
X=df1.drop(columns=['Price'])
y=np.log(df1['Price'])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.15,random_state=2)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge
from sklearn.metrics import r2_score,mean_absolute_error
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor,ExtraTreesRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor

# %%
df1.head(1)
# Out:
#   Company   TypeName  Ram  Weight       Price  TouchScreen  IPS         ppi  \
# 0   Apple  Ultrabook    8    1.37  71378.6832            0    1  226.983005
#
#        Cpu_Brand  SSD  Hybrid Gpu Brand   os
# 0  Intel Core i5  128       0     Intel  Mac

# %% [markdown]
# # Linear Regression

# %%
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2=LinearRegression()

pipe=Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred=pipe.predict(X_test)

print("r2_score",r2_score(y_test,y_pred))
print("MSE",mean_absolute_error(y_test,y_pred))
# Out:
# r2_score 0.8041908754761893
# MSE 0.21466093500470232

# %% [markdown]
# # ridge

# %%
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2=Ridge(alpha=10)

pipe=Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred=pipe.predict(X_test)

print("r2_score",r2_score(y_test,y_pred))
print("MSE",mean_absolute_error(y_test,y_pred))
# Out:
# r2_score 0.8057887440557312
# MSE 0.2157026484649496

# %% [markdown]
# # Lasso

# %%
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2=Lasso(alpha=0.001)

pipe=Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred=pipe.predict(X_test)

print("r2_score",r2_score(y_test,y_pred))
print("MSE",mean_absolute_error(y_test,y_pred))
# Out:
# r2_score 0.7991620132205342
# MSE 0.21801388790068638

# %% [markdown]
# # Knn

# %%
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2=KNeighborsRegressor(n_neighbors=3)

pipe=Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred=pipe.predict(X_test)

print("r2_score",r2_score(y_test,y_pred))
print("MSE",mean_absolute_error(y_test,y_pred))
# Out:
# r2_score 0.818614720114214
# MSE 0.19723738594957954

# %% [markdown]
# # Decision Tree

# %%
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2=DecisionTreeRegressor(max_depth=10)

pipe=Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred=pipe.predict(X_test)

print("r2_score",r2_score(y_test,y_pred))
print("MSE",mean_absolute_error(y_test,y_pred))
# Out:
# r2_score 0.8271451240949372
# MSE 0.19445564548200464

# %% [markdown]
# # SVM

# %%
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2=SVR(kernel='rbf',C=10000,epsilon=0.1)

pipe=Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred=pipe.predict(X_test)

print("r2_score",r2_score(y_test,y_pred))
print("MSE",mean_absolute_error(y_test,y_pred))
# Out:
# r2_score 0.6869279364188327
# MSE 0.20558029000506214

# %% [markdown]
# # Random Forest

# %%
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2=RandomForestRegressor(n_estimators=100,
                           random_state=5,
                           max_samples=0.5,
                           max_features=0.75,
                           max_depth=15)

pipe=Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred=pipe.predict(X_test)

print("r2_score",r2_score(y_test,y_pred))
print("MSE",mean_absolute_error(y_test,y_pred))
# Out:
# r2_score 0.8751444081184182
# MSE 0.16540795693237223

# %% [markdown]
# # Extra Trees

# %%
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2=ExtraTreesRegressor(n_estimators=100,
                           random_state=3,
                           max_samples=0.5,
                           max_features=0.75,
                           max_depth=15,
                         bootstrap=True)

pipe=Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred=pipe.predict(X_test)

print("r2_score",r2_score(y_test,y_pred))
print("MSE",mean_absolute_error(y_test,y_pred))
# Out:
# r2_score 0.8799378197572825
# MSE 0.16644398245946426

# %% [markdown]
# # AdaBoost

# %%
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2=AdaBoostRegressor(n_estimators=15,learning_rate=1.0)

pipe=Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred=pipe.predict(X_test)

print("r2_score",r2_score(y_test,y_pred))
print("MSE",mean_absolute_error(y_test,y_pred))
# Out:
# r2_score 0.7897926906275181
# MSE 0.23300466650394366

# %% [markdown]
# # Gradient Boosting

# %%
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2=GradientBoostingRegressor(n_estimators=500)

pipe=Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred=pipe.predict(X_test)

print("r2_score",r2_score(y_test,y_pred))
print("MSE",mean_absolute_error(y_test,y_pred))
# Out:
# r2_score 0.8780111990202366
# MSE 0.16332512073830366

# %% [markdown]
# # Voting

# %%
from sklearn.ensemble import VotingRegressor,StackingRegressor

# %%
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')


rf=RandomForestRegressor(n_estimators=350,random_state=3,max_samples=0.5,max_features=0.75,max_depth=15)
gdbt=GradientBoostingRegressor(n_estimators=100,max_features=0.5)
xgb=XGBRegressor(n_estimators=25,learning_rate=0.3,max_depth=5)
lr=LinearRegression()
et=ExtraTreesRegressor(n_estimators=100,random_state=3,max_samples=0.5,max_features=0.75,max_depth=10,bootstrap=True)

step2 = VotingRegressor([('rf', rf), ('gbdt', gdbt), ('xgb',xgb), ('et',et)],weights=[5,1,1,1])

pipe=Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred=pipe.predict(X_test)

print("r2_score",r2_score(y_test,y_pred))
print("MSE",mean_absolute_error(y_test,y_pred))
# Out:
# r2_score 0.881584859012546
# MSE 0.16461393153384093

# %% [markdown]
# # Stacking

# %%
from sklearn.ensemble import VotingRegressor,StackingRegressor

step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')


estimators = [
    ('rf', RandomForestRegressor(n_estimators=350,random_state=3,max_samples=0.5,max_features=0.75,max_depth=15)),
    ('gbdt',GradientBoostingRegressor(n_estimators=100,max_features=0.5)),
    ('xgb', XGBRegressor(n_estimators=25,learning_rate=0.3,max_depth=5))
]

step2 = StackingRegressor(estimators=estimators, final_estimator=Ridge(alpha=100))

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8736131040040569
# MAE 0.17313400983673868
